# %%
#¡¡¡¡IMPORTANT NOTE!!!!
#The code requires a column with the smiles strings whose header must be named as: Smiles


import pandas as pd
import rdkit
from rdkit import Chem
from rdkit.Chem import SanitizeMol
from rdkit.Chem import RemoveHs
from rdkit.Chem import AssignStereochemistry

#pip install molvs
from molvs.metal import MetalDisconnector
from molvs.fragment import LargestFragmentChooser
from molvs.normalize import Normalizer
from molvs.charge import Reionizer, Uncharger
from molvs import validate_smiles

#from molvs.standardize import Standardizer
#from molvs import standardize_smiles

# %%
#Import the file that contain the smiles strings
df=pd.read_excel('input_file.xlsx') #Change the file name to the name of your file that contains the smiles strings.
#df=pd.read_csv('name_of_the_database_file.csv')

# %%
#NOTE: If it is intended to determine the canonical tautomer it is important to take into account that the rdkit and molvs functions for this purpose
#sometimes don't preserve the stereochemistry, particularly it is adviced to use molvs over rdkit, since molvs presents this problem with less frequency.

def curation(x,y):
    try:
        mol = Chem.MolFromSmiles(x, sanitize=True) # After constructing the molecule to a format where rdkit can work with the molecule, it is applied the function Chem.SanitizeMol() By default sanitize is always True, but here is shown this parameter to remember that this function includes the sanitize function        
        #Chem.SanitizeMol(mol)                                   # Modifies directly the molecule that is why is not neccesary to include 'mol=' .The sanitize function makes the following: kekulize, check valencies, set aromaticity, conjugation and hybridization. Not recommended to not use sanitize, because in some cases the stereochemistry of the original molecule is not imported and preserved when sanitize is not applied.
        mol = Chem.RemoveHs(mol)                                 # Removal of explicit hydrogens. Some rdkit functions may trouble with molecules with explicit hydrogens such as some functions to calculate physicochemical properties
        mol = MetalDisconnector().disconnect(mol)                # Disconnects metal atoms that are covalently bonded to non-metals.
        mol = LargestFragmentChooser().choose(mol)               # From the molecules that used to be connected with metals or another salts, just the largest fragment is kept.
        mol = Normalizer().normalize(mol)                        # Apply a series of Normalization transforms to correct represent with their charge some functional groups and recombine charges.
        mol = Reionizer().reionize(mol)                          # Ensure the strongest acid groups protonate first in partially ionized molecules. For some reason this function just works in molecules with three or more ionized groups and not in molecules with just two ionized functional groups.
        mol = Uncharger().uncharge(mol)                          # Attempts to neutralize the molecules. Partially ionized molecules will remain without changes.
        Chem.AssignStereochemistry(mol, force=True, cleanIt=True) # Modifies directly the molecule that is why is not neccesary to include 'mol=' .Recalculation of stereochemistry to assure that the original stereochemistry is preserved.
        mol = Chem.MolToSmiles(mol, isomericSmiles=True)                               # Returns the canonical SMILES string for a molecule. The canonical strings generated by rdkit may be different from the canonical SMILES generated by other software. The generated canonical SMILES must be comparable to the ones in ChEMBL since the SMILES strings in ChEMBL were generated with rdkit: https://chembl.gitbook.io/chembl-interface-documentation/frequently-asked-questions/drug-and-compound-questions#how-are-the-smiles-and-inchi-created-for-chembl
                                                                                       # By default isomericSmiles is True, nonetheless the parameter is showed to remember that can be recovered the smiles without the stereochemistry information.
        print(f"{y} processed row")                                                    # Print the index of the processed row
        return mol                                                                     
    except:
        print(f"{y} not processed row")
        pass
        
df["Smiles_curated"] = [curation(i,j) for i,j in zip(df["Smiles"], df.index)]

#Eliminate the empty rows from the column 'Smiles_curated'
#Since the generated SMILES strings from the curation process are canonical won't be two different molecules with the same SMILES string. 
df= df.dropna(subset=['Smiles_curated'])

#This two lines are for the last part of the code that generates a table with the pairs of the duplicated values that later are eliminated
# Filter rows with duplicate values in 'Smiles_curated'
df2=df
duplicates = df2[df2.duplicated('Smiles_curated', keep=False)]

# Remove duplicate rows based on 'Smiles_curated' column, keeping just the first row
df = df.drop_duplicates(subset=['Smiles_curated'], keep='first')


# Alternative ways to call the molvs functions. 
#MetalDisconnector as example.
# mol = self.disconnect_metals(mol) #In the standardizer class was defined MetalDisconnector as disconnect_metals, the remaining classes also were redifined
# mol = MetalDisconnector()(mol)
# Out:
# 0 processed row
# 1 processed row
# 2 processed row
# 3 processed row
# 4 processed row
# 5 processed row
# 6 processed row
# 7 processed row
# 8 processed row
# 9 processed row
# 10 processed row
# 11 processed row
# 12 processed row
# 13 processed row
# 14 processed row
# 15 processed row
# 16 processed row
# 17 processed row
# 18 processed row
# 19 processed row
# 20 processed row
# 21 processed row
# 22 processed row
# 23 processed row
# 24 processed row
# 25 processed row
# 26 processed row
# 27 processed row
# 28 processed row
# 29 processed row
# 30 processed row
# 31 processed row
# 32 processed row
# 33 processed row
# 34 processed row
# 35 processed row
# 36 processed row
# 37 processed row
# 38 processed row
# 39 processed row
# 40 processed row
# 41 processed row
# 42 processed row
# 43 processed row
# 44 processed row
# 45 processed row
# 46 processed row
# 47 processed row
# 48 processed row
# 49 processed row
# 50 processed row
# 51 processed row
# 52 processed row
# 53 processed row
# 54 processed row
# 55 processed row
# 56 processed row
# 57 processed row
# 58 processed row
# 59 processed row
# 60 processed row
# 61 processed row
# 62 processed row
# 63 processed row
# 64 processed row
# 65 processed row
# 66 processed row
# 67 processed row
# 68 processed row
# 69 processed row
# 70 processed row
# 71 processed row
# 72 processed row
# 73 processed row
# 74 processed row
# 75 processed row
# 76 processed row
# 77 processed row
# 78 processed row
# 79 processed row
# 80 processed row
# 81 processed row
# 82 processed row
# 83 processed row
# 84 processed row
# 85 processed row
# 86 processed row
# 87 processed row
# 88 processed row
# 89 processed row
# 90 processed row
# 91 processed row
# 92 processed row
# 93 processed row
# 94 processed row
# 95 processed row
# 96 processed row
# 97 processed row
# 98 processed row
# 99 processed row
# 100 processed row
# 101 processed row
# 102 processed row
# 103 processed row
# 104 processed row
# 105 processed row
# 106 processed row
# 107 processed row
# 108 processed row
# 109 processed row
# 110 processed row
# 111 processed row
# 112 processed row
# 113 processed row
# 114 processed row
# 115 processed row
# 116 processed row
# 117 processed row
# 118 processed row
# 119 processed row
# 120 processed row
# 121 processed row
# 122 processed row
# 123 processed row
# 124 processed row
# 125 processed row
# 126 processed row
# 127 processed row
# 128 processed row
# 129 processed row
# 130 processed row
# 131 processed row
# 132 processed row
# 133 processed row
# 134 processed row
# 135 processed row
# 136 processed row
# 137 processed row
# 138 processed row
# 139 processed row
# 140 processed row
# 141 processed row
# 142 processed row
# 143 processed row
# 144 processed row
# 145 processed row
# 146 processed row
# 147 processed row
# 148 processed row
# 149 processed row
# 150 processed row
# 151 processed row
# 152 processed row
# 153 processed row
# 154 processed row
# 155 processed row
# 156 processed row
# 157 processed row
# 158 processed row
# 159 processed row
# 160 processed row
# 161 processed row
# 162 processed row
# 163 processed row
# 164 processed row
# 165 processed row
# 166 processed row
# 167 processed row
# 168 processed row
# 169 processed row
# 170 processed row
# 171 processed row
# 172 processed row
# 173 processed row
# 174 processed row
# 175 processed row
# 176 processed row
# 177 processed row
# 178 processed row
# 179 processed row
# 180 processed row
# 181 processed row
# 182 processed row
# 183 processed row
# 184 processed row
# 185 processed row
# 186 processed row
# 187 processed row
# 188 processed row
# 189 processed row
# 190 processed row
# 191 processed row
# 192 processed row
# 193 processed row
# 194 processed row
# 195 processed row
# 196 processed row
# 197 processed row
# 198 processed row
# 199 processed row
# 200 processed row
# 201 processed row
# 202 processed row
# 203 processed row
# 204 processed row
# 205 processed row
# 206 processed row
# 207 processed row
# 208 processed row
# 209 processed row
# 210 processed row
# 211 processed row
# 212 processed row
# 213 processed row
# 214 processed row
# 215 processed row
# 216 processed row
# 217 processed row
# 218 processed row
# 219 processed row
# 220 processed row
# 221 processed row
# 222 processed row
# 223 processed row
# 224 processed row
# 225 processed row
# 226 processed row
# 227 processed row
# 228 processed row
# 229 processed row
# 230 processed row
# 231 processed row
# 232 processed row
# 233 processed row
# 234 processed row
# 235 processed row
# 236 processed row
# 237 processed row
# 238 processed row
# 239 processed row
# 240 processed row
# 241 processed row
# 242 processed row
# 243 processed row
# 244 processed row
# 245 processed row
# 246 processed row
# 247 processed row
# 248 processed row
# 249 processed row
# 250 processed row
# 251 processed row
# 252 processed row
# 253 processed row
# 254 processed row
# 255 processed row
# 256 processed row
# 257 processed row
# 258 processed row
# 259 processed row
# 260 processed row
# 261 processed row
# 262 processed row
# 263 processed row
# 264 processed row
# 265 processed row
# 266 processed row
# 267 processed row
# 268 processed row
# 269 processed row
# 270 processed row
# 271 processed row
# 272 processed row
# 273 processed row
# 274 processed row
# 275 processed row
# 276 processed row
# 277 processed row
# 278 processed row
# 279 processed row
# 280 processed row
# 281 processed row
# 282 processed row
# 283 processed row
# 284 processed row
# 285 processed row
# 286 processed row
# 287 processed row
# 288 processed row
# 289 processed row
# 290 processed row
# 291 processed row
# 292 processed row
# 293 processed row
# 294 processed row
# 295 processed row
# 296 processed row
# 297 processed row
# 298 processed row
# 299 processed row
# 300 processed row
# 301 processed row
# 302 processed row
# 303 processed row
# 304 processed row
# 305 processed row
# 306 processed row
# 307 processed row
# 308 processed row
# 309 processed row
# 310 processed row
# 311 processed row
# 312 processed row
# 313 processed row
# 314 processed row
# 315 processed row
# 316 processed row
# 317 processed row
# 318 processed row
# 319 processed row
# 320 processed row
# 321 processed row
# 322 processed row
# 323 processed row
# 324 processed row
# 325 processed row
# 326 processed row
# 327 processed row
# 328 processed row
# 329 processed row
# 330 processed row
# 331 processed row
# 332 processed row
# 333 processed row
# 334 processed row
# 335 processed row
# 336 processed row
# 337 processed row
# 338 processed row
# 339 processed row
# 340 processed row
# 341 processed row
# 342 processed row
# 343 processed row
# 344 processed row
# 345 processed row
# 346 processed row
# 347 processed row
# 348 processed row
# 349 processed row
# 350 processed row
# 351 processed row
# 352 processed row
# 353 processed row
# 354 processed row
# 355 processed row
# 356 processed row
# 357 processed row
# 358 processed row
# 359 processed row
# 360 processed row
# 361 processed row
# 362 processed row
# 363 processed row
# 364 processed row
# 365 processed row
# 366 processed row
# 367 processed row
# 368 processed row
# 369 processed row
# 370 processed row
# 371 processed row
# 372 processed row
# 373 processed row
# 374 processed row
# 375 processed row
# 376 processed row
# 377 processed row
# 378 processed row
# 379 processed row
# 380 processed row
# 381 processed row
# 382 processed row
# 383 processed row
# 384 processed row
# 385 processed row
# 386 processed row
# 387 processed row
# 388 processed row
# 389 processed row
# 390 processed row
# 391 processed row
# 392 processed row
# 393 processed row
# 394 processed row
# 395 processed row
# 396 processed row
# 397 processed row
# 398 processed row
# 399 processed row
# 400 processed row
# 401 processed row
# 402 processed row
# 403 processed row
# 404 processed row
# 405 processed row
# 406 processed row
# 407 processed row
# 408 processed row
# 409 processed row
# 410 processed row
# 411 processed row
# 412 processed row
# 413 processed row
# 414 processed row
# 415 processed row
# 416 processed row
# 417 processed row
# 418 processed row
# 419 processed row
# 420 processed row
# 421 processed row
# 422 processed row
# 423 processed row
# 424 processed row
# 425 processed row
# 426 processed row
# 427 processed row
# 428 processed row
# 429 processed row
# 430 processed row
# 431 processed row
# 432 processed row
# 433 processed row
# 434 processed row
# 435 processed row
# 436 processed row
# 437 processed row
# 438 processed row
# 439 processed row
# 440 processed row
# 441 processed row
# 442 processed row
# 443 processed row
# 444 processed row
# 445 processed row
# 446 processed row
# 447 processed row
# 448 processed row
# 449 processed row
# 450 processed row
# 451 processed row
# 452 processed row
# 453 processed row
# 454 processed row
# 455 processed row
# 456 processed row
# 457 processed row
# 458 processed row
# 459 processed row
# 460 processed row
# 461 processed row
# 462 processed row
# 463 processed row
# 464 processed row
# 465 processed row
# 466 processed row
# 467 processed row
# 468 processed row
# 469 processed row
# 470 processed row
# 471 processed row
# 472 processed row
# 473 processed row
# 474 processed row
# 475 processed row
# 476 processed row
# 477 processed row
# 478 processed row
# 479 processed row
# 480 processed row
# 481 processed row
# 482 processed row
# 483 processed row
# 484 processed row
# 485 processed row
# 486 processed row
# 487 processed row
# 488 processed row
# 489 processed row
# 490 processed row
# 491 processed row
# 492 processed row
# 493 processed row
# 494 processed row
# 495 processed row
# 496 processed row
# 497 processed row
# 498 processed row
# 499 processed row
# 500 processed row
# 501 processed row
# 502 processed row
# 503 processed row
# 504 processed row
# 505 processed row
# 506 processed row
# 507 processed row
# 508 processed row
# 509 processed row
# 510 processed row
# 511 processed row
# 512 processed row
# 513 processed row
# 514 processed row
# 515 processed row
# 516 processed row
# 517 processed row
# 518 processed row
# 519 processed row
# 520 processed row
# 521 processed row
# 522 processed row
# 523 processed row
# 524 processed row
# 525 processed row
# 526 processed row
# 527 processed row
# 528 processed row
# 529 processed row
# 530 processed row
# 531 processed row
# 532 processed row
# 533 processed row
# 534 processed row
# 535 processed row
# 536 processed row
# 537 processed row
# 538 processed row
# 539 processed row
# 540 processed row
# 541 processed row
# 542 processed row
# 543 processed row
# 544 processed row
# 545 processed row
# 546 processed row
# 547 processed row
# 548 processed row
# 549 processed row
# 550 processed row
# 551 processed row
# 552 processed row
# 553 processed row
# 554 processed row
# 555 processed row
# 556 processed row
# 557 processed row
# 558 processed row
# 559 processed row
# 560 processed row
# 561 processed row
# 562 processed row
# 563 processed row
# 564 processed row
# 565 processed row
# 566 processed row
# 567 processed row
# 568 processed row
# 569 processed row
# 570 processed row
# 571 processed row
# 572 processed row
# 573 processed row
# 574 processed row
# 575 processed row
# 576 processed row
# 577 processed row
# 578 processed row
# 579 processed row
# 580 processed row
# 581 processed row
# 582 processed row
# 583 processed row
# 584 processed row
# 585 processed row
# 586 processed row
# 587 processed row
# 588 processed row
# 589 processed row
# 590 processed row
# 591 processed row
# 592 processed row
# 593 processed row
# 594 processed row
# 595 processed row
# 596 processed row
# 597 processed row
# 598 processed row
# 599 processed row
# 600 processed row
# 601 processed row
# 602 processed row
# 603 processed row
# 604 processed row
# 605 processed row
# 606 processed row
# 607 processed row
# 608 processed row
# 609 processed row
# 610 processed row
# 611 processed row
# 612 processed row
# 613 processed row
# 614 processed row
# 615 processed row
# 616 processed row
# 617 processed row
# 618 processed row
# 619 processed row
# 620 processed row
# 621 processed row
# 622 processed row
# 623 processed row
# 624 processed row
# 625 processed row
# 626 processed row
# 627 processed row
# 628 processed row
# 629 processed row
# 630 processed row
# 631 processed row
# 632 processed row
# 633 processed row
# 634 processed row
# 635 processed row
# 636 processed row
# 637 processed row
# 638 processed row
# 639 processed row
# 640 processed row
# 641 processed row
# 642 processed row
# 643 processed row
# 644 processed row
# 645 processed row
# 646 processed row
# 647 processed row
# 648 processed row
# 649 processed row
# 650 processed row
# 651 processed row
# 652 processed row
# 653 processed row
# 654 processed row
# 655 processed row
# 656 processed row
# 657 processed row
# 658 processed row
# 659 processed row
# 660 processed row
# 661 processed row
# 662 processed row
# 663 processed row
# 664 processed row
# 665 processed row
# 666 processed row
# 667 processed row
# 668 processed row
# 669 processed row
# 670 processed row
# 671 processed row
# 672 processed row
# 673 processed row
# 674 processed row
# 675 processed row
# 676 processed row
# 677 processed row
# 678 processed row
# 679 processed row
# 680 processed row
# 681 processed row
# 682 processed row
# 683 processed row
# 684 processed row
# 685 processed row
# 686 processed row
# 687 processed row
# 688 processed row
# 689 processed row
# 690 processed row
# 691 processed row
# 692 processed row
# 693 processed row
# 694 processed row
# 695 processed row
# 696 processed row
# 697 processed row
# 698 processed row
# 699 processed row
# 700 processed row
# 701 processed row
# 702 processed row
# 703 processed row
# 704 processed row
# 705 processed row
# 706 processed row
# 707 processed row
# 708 processed row
# 709 processed row
# 710 processed row
# 711 processed row
# 712 processed row
# 713 processed row
# 714 processed row
# 715 processed row
# 716 processed row
# 717 processed row
# 718 processed row
# 719 processed row
# 720 processed row
# 721 processed row
# 722 processed row
# 723 processed row
# 724 processed row
# 725 processed row
# 726 processed row
# 727 processed row
# 728 processed row
# 729 processed row
# 730 processed row
# 731 processed row
# 732 processed row
# 733 processed row
# 734 processed row
# 735 processed row
# 736 processed row
# 737 processed row
# 738 processed row
# 739 processed row
# 740 processed row
# 741 processed row
# 742 processed row
# 743 processed row
# 744 processed row
# 745 processed row
# 746 processed row
# 747 processed row
# 748 processed row
# 749 processed row
# 750 processed row
# 751 processed row
# 752 processed row
# 753 processed row
# 754 processed row
# 755 processed row
# 756 processed row
# 757 processed row
# 758 processed row
# 759 processed row
# 760 processed row
# 761 processed row
# 762 processed row
# 763 processed row
# 764 processed row
# 765 processed row
# 766 processed row
# 767 processed row
# 768 processed row
# 769 processed row
# 770 processed row
# 771 processed row
# 772 processed row
# 773 processed row
# 774 processed row
# 775 processed row
# 776 processed row
# 777 processed row
# 778 processed row
# 779 processed row
# 780 processed row
# 781 processed row
# 782 processed row
# 783 processed row
# 784 processed row
# 785 processed row
# 786 processed row
# 787 processed row
# 788 processed row
# 789 processed row
# 790 processed row
# 791 processed row
# 792 processed row
# 793 processed row
# 794 processed row
# 795 processed row
# 796 processed row
# 797 processed row
# 798 processed row
# 799 processed row
# 800 processed row
# 801 processed row
# 802 processed row
# 803 processed row
# 804 processed row
# 805 processed row
# 806 processed row
# 807 processed row
# 808 processed row
# 809 processed row
# 810 processed row
# 811 processed row
# 812 processed row
# 813 processed row
# 814 processed row
# 815 processed row
# 816 processed row
# 817 processed row
# 818 processed row
# 819 processed row
# 820 processed row
# 821 processed row
# 822 processed row
# 823 processed row
# 824 processed row
# 825 processed row
# 826 processed row
# 827 processed row
# 828 processed row
# 829 processed row
# 830 processed row
# 831 processed row
# 832 processed row
# 833 processed row
# 834 processed row
# 835 processed row
# 836 processed row
# 837 processed row
# 838 processed row
# 839 processed row
# 840 processed row
# 841 processed row
# 842 processed row
# 843 processed row
# 844 processed row
# 845 processed row
# 846 processed row
# 847 processed row
# 848 processed row
# 849 processed row
# 850 processed row
# 851 processed row
# 852 processed row
# 853 processed row
# 854 processed row
# 855 processed row
# 856 processed row
# 857 processed row
# 858 processed row
# 859 processed row
# 860 processed row
# 861 processed row
# 862 processed row
# 863 processed row
# 864 processed row
# 865 processed row
# 866 processed row
# 867 processed row
# 868 processed row
# 869 processed row
# 870 processed row
# 871 processed row
# 872 processed row
# 873 processed row
# 874 processed row
# 875 processed row
# 876 processed row
# 877 processed row
# 878 processed row
# 879 processed row
# 880 processed row
# 881 processed row
# 882 processed row
# 883 processed row
# 884 processed row
# 885 processed row
# 886 processed row
# 887 processed row
# 888 processed row
# 889 processed row
# 890 processed row
# 891 processed row
# 892 processed row
# 893 processed row
# 894 processed row
# 895 processed row
# 896 processed row
# 897 processed row
# 898 processed row
# 899 processed row
# 900 processed row
# 901 processed row
# 902 processed row
# 903 processed row
# 904 processed row
# 905 processed row
# 906 processed row
# 907 processed row
# 908 processed row
# 909 processed row
# 910 processed row
# 911 processed row
# 912 processed row
# 913 processed row
# 914 processed row
# 915 processed row
# 916 processed row
# 917 processed row
# 918 processed row
# 919 processed row
# 920 processed row
# 921 processed row
# 922 processed row
# 923 processed row
# 924 processed row
# 925 processed row
# 926 processed row
# 927 processed row
# 928 processed row
# 929 processed row
# 930 processed row
# 931 processed row
# 932 processed row
# 933 processed row
# 934 processed row
# 935 processed row
# 936 processed row
# 937 processed row
# 938 processed row
# 939 processed row
# 940 processed row
# 941 processed row
# 942 processed row
# 943 processed row
# 944 processed row
# 945 processed row
# 946 processed row
# 947 processed row
# 948 processed row
# 949 processed row
# 950 processed row
# 951 processed row
# 952 processed row
# 953 processed row
# 954 processed row
# 955 processed row
# 956 processed row
# 957 processed row
# 958 processed row
# 959 processed row
# 960 processed row
# 961 processed row
# 962 processed row
# 963 processed row
# 964 processed row
# 965 processed row
# 966 processed row
# 967 processed row
# 968 processed row
# 969 processed row
# 970 processed row
# 971 processed row
# 972 processed row
# 973 processed row
# 974 processed row
# 975 processed row
# 976 processed row
# 977 processed row
# 978 processed row
# 979 processed row
# 980 processed row
# 981 processed row
# 982 processed row
# 983 processed row
# 984 processed row
# 985 processed row
# 986 processed row
# 987 processed row
# 988 processed row
# 989 processed row
# 990 processed row
# 991 processed row
# 992 processed row
# 993 processed row
# 994 processed row
# 995 processed row
# 996 processed row
# 997 processed row
# 998 processed row
# 999 processed row
# 1000 processed row
# 1001 processed row
# 1002 processed row
# 1003 processed row
# 1004 processed row
# 1005 processed row
# 1006 processed row
# 1007 processed row
# 1008 processed row
# 1009 processed row
# 1010 processed row
# 1011 processed row
# 1012 processed row
# 1013 processed row
# 1014 processed row
# 1015 processed row
# 1016 processed row
# 1017 processed row
# 1018 processed row
# 1019 processed row
# 1020 processed row
# 1021 processed row
# 1022 processed row
# 1023 processed row
# 1024 processed row
# 1025 processed row
# 1026 processed row
# 1027 processed row
# 1028 processed row
# 1029 processed row
# 1030 processed row
# 1031 processed row
# 1032 processed row
# 1033 processed row
# 1034 processed row
# 1035 processed row
# 1036 processed row
# 1037 processed row
# 1038 processed row
# 1039 processed row
# 1040 processed row
# 1041 processed row
# 1042 processed row
# 1043 processed row
# 1044 processed row
# 1045 processed row
# 1046 processed row
# 1047 processed row
# 1048 processed row
# 1049 processed row
# 1050 processed row
# 1051 processed row
# 1052 processed row
# 1053 processed row
# 1054 processed row
# 1055 processed row
# 1056 processed row
# 1057 processed row
# 1058 processed row
# 1059 processed row
# 1060 processed row
# 1061 processed row
# 1062 processed row
# 1063 processed row
# 1064 processed row
# 1065 processed row
# 1066 processed row
# 1067 processed row
# 1068 processed row
# 1069 processed row
# 1070 processed row
# 1071 processed row
# 1072 processed row
# 1073 processed row
# 1074 processed row
# 1075 processed row
# 1076 processed row
# 1077 processed row
# 1078 processed row
# 1079 processed row
# 1080 processed row
# 1081 processed row
# 1082 processed row
# 1083 processed row
# 1084 processed row
# 1085 processed row
# 1086 processed row
# 1087 processed row
# 1088 processed row
# 1089 processed row
# 1090 processed row
# 1091 processed row
# 1092 processed row
# 1093 processed row
# 1094 processed row
# 1095 processed row
# 1096 processed row
# 1097 processed row
# 1098 processed row
# 1099 processed row
# 1100 processed row
# 1101 processed row
# 1102 processed row
# 1103 processed row
# 1104 processed row
# 1105 processed row
# 1106 processed row
# 1107 processed row
# 1108 processed row
# 1109 processed row
# 1110 processed row
# 1111 processed row
# 1112 processed row
# 1113 processed row
# 1114 processed row
# 1115 processed row
# 1116 processed row
# 1117 processed row
# 1118 processed row
# 1119 processed row
# 1120 processed row
# 1121 processed row
# 1122 processed row
# 1123 processed row
# 1124 processed row
# 1125 processed row
# 1126 processed row
# 1127 processed row
# 1128 processed row
# 1129 processed row
# 1130 processed row
# 1131 processed row
# 1132 processed row
# 1133 processed row
# 1134 processed row
# 1135 processed row
# 1136 processed row
# 1137 processed row
# 1138 processed row
# 1139 processed row
# 1140 processed row
# 1141 processed row
# 1142 processed row
# 1143 processed row
# 1144 processed row
# 1145 processed row
# 1146 processed row
# 1147 processed row
# 1148 processed row
# 1149 processed row
# 1150 processed row
# 1151 processed row
# 1152 processed row
# 1153 processed row
# 1154 processed row
# 1155 processed row
# 1156 processed row
# 1157 processed row
# 1158 processed row
# 1159 processed row
# 1160 processed row
# 1161 processed row
# 1162 processed row
# 1163 processed row
# 1164 processed row
# 1165 processed row
# 1166 processed row
# 1167 processed row
# 1168 processed row
# 1169 processed row
# 1170 processed row
# 1171 processed row
# 1172 processed row
# 1173 processed row
# 1174 processed row
# 1175 processed row
# 1176 processed row
# 1177 processed row
# 1178 processed row
# 1179 processed row
# 1180 processed row
# 1181 processed row
# 1182 processed row
# 1183 processed row
# 1184 processed row
# 1185 processed row
# 1186 processed row
# 1187 processed row
# 1188 processed row
# 1189 processed row
# 1190 processed row
# 1191 processed row
# 1192 processed row
# 1193 processed row
# 1194 processed row
# 1195 processed row
# 1196 processed row
# 1197 processed row
# 1198 processed row
# 1199 processed row
# 1200 processed row
# 1201 processed row
# 1202 processed row
# 1203 processed row
# 1204 processed row
# 1205 processed row
# 1206 processed row
# 1207 processed row
# 1208 processed row
# 1209 processed row
# 1210 processed row
# 1211 processed row
# 1212 processed row
# 1213 processed row
# 1214 processed row
# 1215 processed row
# 1216 processed row
# 1217 processed row
# 1218 processed row
# 1219 processed row
# 1220 processed row
# 1221 processed row
# 1222 processed row
# 1223 processed row
# 1224 processed row
# 1225 processed row
# 1226 processed row
# 1227 processed row
# 1228 processed row
# 1229 processed row
# 1230 processed row
# 1231 processed row
# 1232 processed row
# 1233 processed row
# 1234 processed row
# 1235 processed row
# 1236 processed row
# 1237 processed row
# 1238 processed row
# 1239 processed row
# 1240 processed row
# 1241 processed row
# 1242 processed row
# 1243 processed row
# 1244 processed row
# 1245 processed row
# 1246 processed row
# 1247 processed row
# 1248 processed row
# 1249 processed row
# 1250 processed row
# 1251 processed row
# 1252 processed row
# 1253 processed row
# 1254 processed row
# 1255 processed row
# 1256 processed row
# 1257 processed row
# 1258 processed row
# 1259 processed row
# 1260 processed row
# 1261 processed row
# 1262 processed row
# 1263 processed row
# 1264 processed row
# 1265 processed row
# 1266 processed row
# 1267 processed row
# 1268 processed row
# 1269 processed row
# 1270 processed row
# 1271 processed row
# 1272 processed row
# 1273 processed row
# 1274 processed row
# 1275 processed row
# 1276 processed row
# 1277 processed row
# 1278 processed row
# 1279 processed row
# 1280 processed row
# 1281 processed row
# 1282 processed row
# 1283 processed row
# 1284 processed row
# 1285 processed row
# 1286 processed row
# 1287 processed row
# 1288 processed row
# 1289 processed row
# 1290 processed row
# 1291 processed row
# 1292 processed row
# 1293 processed row
# 1294 processed row
# 1295 processed row
# 1296 processed row
# 1297 processed row
# 1298 processed row
# 1299 processed row
# 1300 processed row
# 1301 processed row
# 1302 processed row
# 1303 processed row
# 1304 processed row
# 1305 processed row
# 1306 processed row
# 1307 processed row
# 1308 processed row
# 1309 processed row
# 1310 processed row
# 1311 processed row
# 1312 processed row
# 1313 processed row
# 1314 processed row
# 1315 processed row
# 1316 processed row
# 1317 processed row
# 1318 processed row
# 1319 processed row
# 1320 processed row
# 1321 processed row
# 1322 processed row
# 1323 processed row
# 1324 processed row
# 1325 processed row
# 1326 processed row
# 1327 processed row
# 1328 processed row
# 1329 processed row
# 1330 processed row
# 1331 processed row
# 1332 processed row
# 1333 processed row
# 1334 processed row
# 1335 processed row
# 1336 processed row
# 1337 processed row
# 1338 processed row
# 1339 processed row
# 1340 processed row
# 1341 processed row
# 1342 processed row
# 1343 processed row
# 1344 processed row
# 1345 processed row
# 1346 processed row
# 1347 processed row
# 1348 processed row
# 1349 processed row
# 1350 processed row
# 1351 processed row
# 1352 processed row
# 1353 processed row
# 1354 processed row
# 1355 processed row
# 1356 processed row
# 1357 processed row
# 1358 processed row
# 1359 processed row
# 1360 processed row
# 1361 processed row
# 1362 processed row
# 1363 processed row
# 1364 processed row
# 1365 processed row
# 1366 processed row
# 1367 processed row
# 1368 processed row
# 1369 processed row
# 1370 processed row
# 1371 processed row
# 1372 processed row
# 1373 processed row
# 1374 processed row
# 1375 processed row
# 1376 processed row
# 1377 processed row
# 1378 processed row
# 1379 processed row
# 1380 processed row
# 1381 processed row
# 1382 processed row
# 1383 processed row
# 1384 processed row
# 1385 processed row
# 1386 processed row
# 1387 processed row
# 1388 processed row
# 1389 processed row
# 1390 processed row
# 1391 processed row
# 1392 processed row
# 1393 processed row
# 1394 processed row
# 1395 processed row
# 1396 processed row
# 1397 processed row
# 1398 processed row
# 1399 processed row
# 1400 processed row
# 1401 processed row
# 1402 processed row
# 1403 processed row
# 1404 processed row
# 1405 processed row
# 1406 processed row
# 1407 processed row
# 1408 processed row
# 1409 processed row
# 1410 processed row
# 1411 processed row
# 1412 processed row
# 1413 processed row
# 1414 processed row
# 1415 processed row
# 1416 processed row
# 1417 processed row
# 1418 processed row
# 1419 processed row
# 1420 processed row
# 1421 processed row
# 1422 processed row
# 1423 processed row
# 1424 processed row
# 1425 processed row
# 1426 processed row
# 1427 processed row
# 1428 processed row
# 1429 processed row
# 1430 processed row
# 1431 processed row
# 1432 processed row
# 1433 processed row
# 1434 processed row
# 1435 processed row
# 1436 processed row
# 1437 processed row
# 1438 processed row
# 1439 processed row
# 1440 processed row
# 1441 processed row
# 1442 processed row
# 1443 processed row
# 1444 processed row
# 1445 processed row
# 1446 processed row
# 1447 processed row
# 1448 processed row
# 1449 processed row
# 1450 processed row
# 1451 processed row
# 1452 processed row
# 1453 processed row
# 1454 processed row
# 1455 processed row
# 1456 processed row
# 1457 processed row
# 1458 processed row
# 1459 processed row
# 1460 processed row
# 1461 processed row
# 1462 processed row
# 1463 processed row
# 1464 processed row
# 1465 processed row
# 1466 processed row
# 1467 processed row
# 1468 processed row
# 1469 processed row
# 1470 processed row
# 1471 processed row
# 1472 processed row
# 1473 processed row
# 1474 processed row
# 1475 processed row
# 1476 processed row
# 1477 processed row
# 1478 processed row
# 1479 processed row
# 1480 processed row
# 1481 processed row
# 1482 processed row
# 1483 processed row
# 1484 processed row
# 1485 processed row
# 1486 processed row
# 1487 processed row
# 1488 processed row
# 1489 processed row
# 1490 processed row
# 1491 processed row
# 1492 processed row
# 1493 processed row
# 1494 processed row
# 1495 processed row
# 1496 processed row
# 1497 processed row
# 1498 processed row
# 1499 processed row
# 1500 processed row
# 1501 processed row
# 1502 processed row
# 1503 processed row
# 1504 processed row
# 1505 processed row
# 1506 processed row
# 1507 processed row
# 1508 processed row
# 1509 processed row
# 1510 processed row
# 1511 processed row
# 1512 processed row
# 1513 processed row
# 1514 processed row
# 1515 processed row
# 1516 processed row
# 1517 processed row
# 1518 processed row
# 1519 processed row
# 1520 processed row
# 1521 processed row
# 1522 processed row
# 1523 processed row
# 1524 processed row
# 1525 processed row
# 1526 processed row
# 1527 processed row
# 1528 processed row
# 1529 processed row
# 1530 processed row
# 1531 processed row
# 1532 processed row
# 1533 processed row
# 1534 processed row
# 1535 processed row
# 1536 processed row
# 1537 processed row
# 1538 processed row
# 1539 processed row
# 1540 processed row
# 1541 processed row
# 1542 processed row
# 1543 processed row
# 1544 processed row
# 1545 processed row
# 1546 processed row
# 1547 processed row
# 1548 processed row
# 1549 processed row
# 1550 processed row
# 1551 processed row
# 1552 processed row
# 1553 processed row
# 1554 processed row
# 1555 processed row
# 1556 processed row
# 1557 processed row
# 1558 processed row
# 1559 processed row
# 1560 processed row
# 1561 processed row
# 1562 processed row
# 1563 processed row
# 1564 processed row
# 1565 processed row
# 1566 processed row
# 1567 processed row
# 1568 processed row
# 1569 processed row
# 1570 processed row
# 1571 processed row
# 1572 processed row
# 1573 processed row
# 1574 processed row
# 1575 processed row
# 1576 processed row
# 1577 processed row
# 1578 processed row
# 1579 processed row
# 1580 processed row
# 1581 processed row
# 1582 processed row
# 1583 processed row
# 1584 processed row
# 1585 processed row
# 1586 processed row
# 1587 processed row
# 1588 processed row
# 1589 processed row
# 1590 processed row
# 1591 processed row
# 1592 processed row
# 1593 processed row
# 1594 processed row
# 1595 processed row
# 1596 processed row
# 1597 processed row
# 1598 processed row
# 1599 processed row
# 1600 processed row
# 1601 processed row
# 1602 processed row
# 1603 processed row
# 1604 processed row
# 1605 processed row
# 1606 processed row
# 1607 processed row
# 1608 processed row
# 1609 processed row
# 1610 processed row
# 1611 processed row
# 1612 processed row
# 1613 processed row
# 1614 processed row
# 1615 processed row
# 1616 processed row
# 1617 processed row
# 1618 processed row
# 1619 processed row
# 1620 processed row
# 1621 processed row
# 1622 processed row
# 1623 processed row
# 1624 processed row
# 1625 processed row
# 1626 processed row
# 1627 processed row
# 1628 processed row
# 1629 processed row
# 1630 processed row
# 1631 processed row
# 1632 processed row
# 1633 processed row
# 1634 processed row
# 1635 processed row
# 1636 processed row
# 1637 processed row
# 1638 processed row
# 1639 processed row
# 1640 processed row
# 1641 processed row
# 1642 processed row
# 1643 processed row
# 1644 processed row
# 1645 processed row
# 1646 processed row
# 1647 processed row
# 1648 processed row
# 1649 processed row
# 1650 processed row
# 1651 processed row
# 1652 processed row
# 1653 processed row
# 1654 processed row
# 1655 processed row
# 1656 processed row
# 1657 processed row
# 1658 processed row
# 1659 processed row
# 1660 processed row
# 1661 processed row
# 1662 processed row
# 1663 processed row
# 1664 processed row
# 1665 processed row
# 1666 processed row
# 1667 processed row
# 1668 processed row
# 1669 processed row
# 1670 processed row
# 1671 processed row
# 1672 processed row
# 1673 processed row
# 1674 processed row
# 1675 processed row
# 1676 processed row
# 1677 processed row
# 1678 processed row
# 1679 processed row
# 1680 processed row
# 1681 processed row
# 1682 processed row
# 1683 processed row
# 1684 processed row
# 1685 processed row
# 1686 processed row
# 1687 processed row
# 1688 processed row
# 1689 processed row
# 1690 processed row
# 1691 processed row
# 1692 processed row
# 1693 processed row
# 1694 processed row
# 1695 processed row
# 1696 processed row
# 1697 processed row
# 1698 processed row
# 1699 processed row
# 1700 processed row
# 1701 processed row
# 1702 processed row
# 1703 processed row
# 1704 processed row
# 1705 processed row
# 1706 processed row
# 1707 processed row
# 1708 processed row
# 1709 processed row
# 1710 processed row
# 1711 processed row
# 1712 processed row
# 1713 processed row
# 1714 processed row
# 1715 processed row
# 1716 processed row
# 1717 processed row
# 1718 processed row
# 1719 processed row
# 1720 processed row
# 1721 processed row
# 1722 processed row
# 1723 processed row
# 1724 processed row
# 1725 processed row
# 1726 processed row
# 1727 processed row
# 1728 processed row
# 1729 processed row
# 1730 processed row
# 1731 processed row
# 1732 processed row
# 1733 processed row
# 1734 processed row
# 1735 processed row
# 1736 processed row
# 1737 processed row
# 1738 processed row
# 1739 processed row
# 1740 processed row
# 1741 processed row
# 1742 processed row
# 1743 processed row
# 1744 processed row
# 1745 processed row
# 1746 processed row
# 1747 processed row
# 1748 processed row
# 1749 processed row
# 1750 processed row
# 1751 processed row
# 1752 processed row
# 1753 processed row
# 1754 processed row
# 1755 processed row
# 1756 processed row
# 1757 processed row
# 1758 processed row
# 1759 processed row
# 1760 processed row
# 1761 processed row
# 1762 processed row
# 1763 processed row
# 1764 processed row
# 1765 processed row
# 1766 processed row
# 1767 processed row
# 1768 processed row
# 1769 processed row
# 1770 processed row
# 1771 processed row
# 1772 processed row
# 1773 processed row
# 1774 processed row
# 1775 processed row
# 1776 processed row
# 1777 processed row
# 1778 processed row
# 1779 processed row
# 1780 processed row
# 1781 processed row
# 1782 processed row
# 1783 processed row
# 1784 processed row
# 1785 processed row
# 1786 processed row
# 1787 processed row
# 1788 processed row
# 1789 processed row
# 1790 processed row
# 1791 processed row
# 1792 processed row
# 1793 processed row
# 1794 processed row
# 1795 processed row
# 1796 processed row
# 1797 processed row
# 1798 processed row
# 1799 processed row
# 1800 processed row
# 1801 processed row
# 1802 processed row
# 1803 processed row
# 1804 processed row
# 1805 processed row
# 1806 processed row
# 1807 processed row
# 1808 processed row
# 1809 processed row
# 1810 processed row
# 1811 processed row
# 1812 processed row
# 1813 processed row
# 1814 processed row
# 1815 processed row
# 1816 processed row
# 1817 processed row
# 1818 processed row
# 1819 processed row
# 1820 processed row
# 1821 processed row
# 1822 processed row
# 1823 processed row
# 1824 processed row
# 1825 processed row
# 1826 processed row
# 1827 processed row
# 1828 processed row
# 1829 processed row
# 1830 processed row
# 1831 processed row
# 1832 processed row
# 1833 processed row
# 1834 processed row
# 1835 processed row
# 1836 processed row
# 1837 processed row
# 1838 processed row
# 1839 processed row
# 1840 processed row
# 1841 processed row
# 1842 processed row
# 1843 processed row
# 1844 processed row
# 1845 processed row
# 1846 processed row
# 1847 processed row
# 1848 processed row
# 1849 processed row
# 1850 processed row
# 1851 processed row
# 1852 processed row
# 1853 processed row
# 1854 processed row
# 1855 processed row
# 1856 processed row
# 1857 processed row
# 1858 processed row
# 1859 processed row
# 1860 processed row
# 1861 processed row
# 1862 processed row
# 1863 processed row
# 1864 processed row
# 1865 processed row
# 1866 processed row
# 1867 processed row
# 1868 processed row
# 1869 processed row
# 1870 processed row
# 1871 processed row
# 1872 processed row
# 1873 processed row
# 1874 processed row
# 1875 processed row
# 1876 processed row
# 1877 processed row
# 1878 processed row
# 1879 processed row
# 1880 processed row
# 1881 processed row
# 1882 processed row
# 1883 processed row
# 1884 processed row
# 1885 processed row
# 1886 processed row
# 1887 processed row
# 1888 processed row
# 1889 processed row
# 1890 processed row
# 1891 processed row
# 1892 processed row
# 1893 processed row
# 1894 processed row
# 1895 processed row
# 1896 processed row
# 1897 processed row
# 1898 processed row
# 1899 processed row
# 1900 processed row
# 1901 processed row
# 1902 processed row
# 1903 processed row
# 1904 processed row
# 1905 processed row
# 1906 processed row
# 1907 processed row
# 1908 processed row
# 1909 processed row
# 1910 processed row
# 1911 processed row
# 1912 processed row
# 1913 processed row
# 1914 processed row
# 1915 processed row
# 1916 processed row
# 1917 processed row
# 1918 processed row
# 1919 processed row
# 1920 processed row
# 1921 processed row
# 1922 processed row
# 1923 processed row
# 1924 processed row
# 1925 processed row
# 1926 processed row
# 1927 processed row
# 1928 processed row
# 1929 processed row
# 1930 processed row
# 1931 processed row
# 1932 processed row
# 1933 processed row
# 1934 processed row
# 1935 processed row
# 1936 processed row
# 1937 processed row
# 1938 processed row
# 1939 processed row
# 1940 processed row
# 1941 processed row
# 1942 processed row
# 1943 processed row
# 1944 processed row
# 1945 processed row
# 1946 processed row
# 1947 processed row
# 1948 processed row
# 1949 processed row
# 1950 processed row
# 1951 processed row
# 1952 processed row
# 1953 processed row
# 1954 processed row
# 1955 processed row
# 1956 processed row
# 1957 processed row
# 1958 processed row
# 1959 processed row
# 1960 processed row
# 1961 processed row
# 1962 processed row
# 1963 processed row
# 1964 processed row
# 1965 processed row
# 1966 processed row
# 1967 processed row
# 1968 processed row
# 1969 processed row
# 1970 processed row
# 1971 processed row
# 1972 processed row
# 1973 processed row
# 1974 processed row
# 1975 processed row
# 1976 processed row
# 1977 processed row
# 1978 processed row
# 1979 processed row
# 1980 processed row
# 1981 processed row
# 1982 processed row
# 1983 processed row
# 1984 processed row
# 1985 processed row
# 1986 processed row
# 1987 processed row
# 1988 processed row
# 1989 processed row
# 1990 processed row
# 1991 processed row
# 1992 processed row
# 1993 processed row
# 1994 processed row
# 1995 processed row
# 1996 processed row
# 1997 processed row
# 1998 processed row
# 1999 processed row
# 2000 processed row
# 2001 processed row
# 2002 processed row
# 2003 processed row
# 2004 processed row
# 2005 processed row
# 2006 processed row
# 2007 processed row
# 2008 processed row
# 2009 processed row
# 2010 processed row
# 2011 processed row
# 2012 processed row
# 2013 processed row
# 2014 processed row
# 2015 processed row
# 2016 processed row
# 2017 processed row
# 2018 processed row
# 2019 processed row
# 2020 processed row
# 2021 processed row
# 2022 processed row
# 2023 processed row
# 2024 processed row
# 2025 processed row
# 2026 processed row
# 2027 processed row
# 2028 processed row
# 2029 processed row
# 2030 processed row
# 2031 processed row
# 2032 processed row
# 2033 processed row
# 2034 processed row
# 2035 processed row
# 2036 processed row
# 2037 processed row
# 2038 processed row
# 2039 processed row
# 2040 processed row
# 2041 processed row
# 2042 processed row
# 2043 processed row
# 2044 processed row
# 2045 processed row
# 2046 processed row
# 2047 processed row
# 2048 processed row
# 2049 processed row
# 2050 processed row
# 2051 processed row
# 2052 processed row
# 2053 processed row
# 2054 processed row
# 2055 processed row
# 2056 processed row
# 2057 processed row
# 2058 processed row
# 2059 processed row
# 2060 processed row
# 2061 processed row
# 2062 processed row
# 2063 processed row
# 2064 processed row
# 2065 processed row
# 2066 processed row
# 2067 processed row
# 2068 processed row
# 2069 processed row
# 2070 processed row
# 2071 processed row
# 2072 processed row
# 2073 processed row
# 2074 processed row
# 2075 processed row
# 2076 processed row
# 2077 processed row
# 2078 processed row
# 2079 processed row
# 2080 processed row
# 2081 processed row
# 2082 processed row
# 2083 processed row
# 2084 processed row
# 2085 processed row
# 2086 processed row
# 2087 processed row
# 2088 processed row
# 2089 processed row
# 2090 processed row
# 2091 processed row
# 2092 processed row
# 2093 processed row
# 2094 processed row
# 2095 processed row
# 2096 processed row
# 2097 processed row
# 2098 processed row
# 2099 processed row
# 2100 processed row
# 2101 processed row
# 2102 processed row
# 2103 processed row
# 2104 processed row
# 2105 processed row
# 2106 processed row
# 2107 processed row
# 2108 processed row
# 2109 processed row
# 2110 processed row
# 2111 processed row
# 2112 processed row
# 2113 processed row
# 2114 processed row
# 2115 processed row
# 2116 processed row
# 2117 processed row
# 2118 processed row
# 2119 processed row
# 2120 processed row
# 2121 processed row
# 2122 processed row
# 2123 processed row
# 2124 processed row
# 2125 processed row
# 2126 processed row
# 2127 processed row
# 2128 processed row
# 2129 processed row
# 2130 processed row
# 2131 processed row
# 2132 processed row
# 2133 processed row
# 2134 processed row
# 2135 processed row
# 2136 processed row
# 2137 processed row
# 2138 processed row
# 2139 processed row
# 2140 processed row
# 2141 processed row
# 2142 processed row
# 2143 processed row
# 2144 processed row
# 2145 processed row
# 2146 processed row
# 2147 processed row
# 2148 processed row
# 2149 processed row
# 2150 processed row
# 2151 processed row
# 2152 processed row
# 2153 processed row
# 2154 processed row
# 2155 processed row
# 2156 processed row
# 2157 processed row
# 2158 processed row
# 2159 processed row
# 2160 processed row
# 2161 processed row
# 2162 processed row
# 2163 processed row
# 2164 processed row
# 2165 processed row
# 2166 processed row
# 2167 processed row
# 2168 processed row
# 2169 processed row
# 2170 processed row
# 2171 processed row
# 2172 processed row
# 2173 processed row
# 2174 processed row
# 2175 processed row
# 2176 processed row
# 2177 processed row
# 2178 processed row
# 2179 processed row
# 2180 processed row
# 2181 processed row
# 2182 processed row
# 2183 processed row
# 2184 processed row
# 2185 processed row
# 2186 processed row
# 2187 processed row
# 2188 processed row
# 2189 processed row
# 2190 processed row
# 2191 processed row
# 2192 processed row
# 2193 processed row
# 2194 processed row
# 2195 processed row
# 2196 processed row
# 2197 processed row
# 2198 processed row
# 2199 processed row
# 2200 processed row
# 2201 processed row
# 2202 processed row
# 2203 processed row
# 2204 processed row
# 2205 processed row
# 2206 processed row
# 2207 processed row
# 2208 processed row
# 2209 processed row
# 2210 processed row
# 2211 processed row
# 2212 processed row
# 2213 processed row
# 2214 processed row
# 2215 processed row
# 2216 processed row
# 2217 processed row
# 2218 processed row
# 2219 processed row
# 2220 processed row
# 2221 processed row
# 2222 processed row
# 2223 processed row
# 2224 processed row
# 2225 processed row
# 2226 processed row
# 2227 processed row
# 2228 processed row
# 2229 processed row
# 2230 processed row
# 2231 processed row
# 2232 processed row
# 2233 processed row
# 2234 processed row
# 2235 processed row
# 2236 processed row
# 2237 processed row
# 2238 processed row
# 2239 processed row
# 2240 processed row
# 2241 processed row
# 2242 processed row
# 2243 processed row
# 2244 processed row
# 2245 processed row
# 2246 processed row
# 2247 processed row
# 2248 processed row
# 2249 processed row
# 2250 processed row
# 2251 processed row
# 2252 processed row
# 2253 processed row
# 2254 processed row
# 2255 processed row
# 2256 processed row
# 2257 processed row
# 2258 processed row
# 2259 processed row
# 2260 processed row
# 2261 processed row
# 2262 processed row
# 2263 processed row
# 2264 processed row
# 2265 processed row
# 2266 processed row
# 2267 processed row
# 2268 processed row
# 2269 processed row
# 2270 processed row
# 2271 processed row
# 2272 processed row
# 2273 processed row
# 2274 processed row
# 2275 processed row
# 2276 processed row
# 2277 processed row
# 2278 processed row
# 2279 processed row
# 2280 processed row
# 2281 processed row
# 2282 processed row
# 2283 processed row
# 2284 processed row
# 2285 processed row
# 2286 processed row
# 2287 processed row
# 2288 processed row
# 2289 processed row
# 2290 processed row
# 2291 processed row
# 2292 processed row
# 2293 processed row
# 2294 processed row
# 2295 processed row
# 2296 processed row
# 2297 processed row
# 2298 processed row
# 2299 processed row
# 2300 processed row
# 2301 processed row
# 2302 processed row
# 2303 processed row
# 2304 processed row
# 2305 processed row
# 2306 processed row
# 2307 processed row
# 2308 processed row
# 2309 processed row
# 2310 processed row
# 2311 processed row
# 2312 processed row
# 2313 processed row
# 2314 processed row
# 2315 processed row
# 2316 processed row
# 2317 processed row
# 2318 processed row
# 2319 processed row
# 2320 processed row
# 2321 processed row
# 2322 processed row
# 2323 processed row
# 2324 processed row
# 2325 processed row
# 2326 processed row
# 2327 processed row
# 2328 processed row
# 2329 processed row
# 2330 processed row
# 2331 processed row
# 2332 processed row
# 2333 processed row
# 2334 processed row
# 2335 processed row
# 2336 processed row
# 2337 processed row
# 2338 processed row
# 2339 processed row
# 2340 processed row
# 2341 processed row
# 2342 processed row
# 2343 processed row
# 2344 processed row
# 2345 processed row
# 2346 processed row
# 2347 processed row
# 2348 processed row
# 2349 processed row
# 2350 processed row
# 2351 processed row
# 2352 processed row
# 2353 processed row
# 2354 processed row
# 2355 processed row
# 2356 processed row
# 2357 processed row
# 2358 processed row
# 2359 processed row
# 2360 processed row
# 2361 processed row
# 2362 processed row
# 2363 processed row
# 2364 processed row
# 2365 processed row
# 2366 processed row
# 2367 processed row
# 2368 processed row
# 2369 processed row
# 2370 processed row
# 2371 processed row
# 2372 processed row
# 2373 processed row
# 2374 processed row
# 2375 processed row
# 2376 processed row
# 2377 processed row
# 2378 processed row
# 2379 processed row
# 2380 processed row
# 2381 processed row
# 2382 processed row
# 2383 processed row
# 2384 processed row
# 2385 processed row
# 2386 processed row
# 2387 processed row
# 2388 processed row
# 2389 processed row
# 2390 processed row
# 2391 processed row
# 2392 processed row
# 2393 processed row
# 2394 processed row
# 2395 processed row
# 2396 processed row
# 2397 processed row
# 2398 processed row
# 2399 processed row
# 2400 processed row
# 2401 processed row
# 2402 processed row
# 2403 processed row
# 2404 processed row
# 2405 processed row
# 2406 processed row
# 2407 processed row
# 2408 processed row
# 2409 processed row
# 2410 processed row
# 2411 processed row
# 2412 processed row
# 2413 processed row
# 2414 processed row
# 2415 processed row
# 2416 processed row
# 2417 processed row
# 2418 processed row
# 2419 processed row
# 2420 processed row
# 2421 processed row
# 2422 processed row
# 2423 processed row
# 2424 processed row
# 2425 processed row
# 2426 processed row
# 2427 processed row
# 2428 processed row
# 2429 processed row
# 2430 processed row
# 2431 processed row
# 2432 processed row
# 2433 processed row
# 2434 processed row
# 2435 processed row
# 2436 processed row
# 2437 processed row
# 2438 processed row
# 2439 processed row
# 2440 processed row
# 2441 processed row
# 2442 processed row
# 2443 processed row
# 2444 processed row
# 2445 processed row
# 2446 processed row
# 2447 processed row
# 2448 processed row
# 2449 processed row
# 2450 processed row
# 2451 processed row
# 2452 processed row
# 2453 processed row
# 2454 processed row
# 2455 processed row
# 2456 processed row
# 2457 processed row
# 2458 processed row
# 2459 processed row
# 2460 processed row
# 2461 processed row
# 2462 processed row
# 2463 processed row
# 2464 processed row
# 2465 processed row
# 2466 processed row
# 2467 processed row
# 2468 processed row
# 2469 processed row
# 2470 processed row
# 2471 processed row
# 2472 processed row
# 2473 processed row
# 2474 processed row
# 2475 processed row
# 2476 processed row
# 2477 processed row
# 2478 processed row
# 2479 processed row
# 2480 processed row
# 2481 processed row
# 2482 processed row
# 2483 processed row
# 2484 processed row
# 2485 processed row
# 2486 processed row
# 2487 processed row
# 2488 processed row
# 2489 processed row
# 2490 processed row
# 2491 processed row
# 2492 processed row
# 2493 processed row
# 2494 processed row
# 2495 processed row
# 2496 processed row
# 2497 processed row
# 2498 processed row
# 2499 processed row
# 2500 processed row
# 2501 processed row
# 2502 processed row
# 2503 processed row
# 2504 processed row
# 2505 processed row
# 2506 processed row
# 2507 processed row
# 2508 processed row
# 2509 processed row
# 2510 processed row
# 2511 processed row
# 2512 processed row
# 2513 processed row
# 2514 processed row
# 2515 processed row
# 2516 processed row
# 2517 processed row
# 2518 processed row
# 2519 processed row
# 2520 processed row
# 2521 processed row
# 2522 processed row
# 2523 processed row
# 2524 processed row
# 2525 processed row
# 2526 processed row
# 2527 processed row
# 2528 processed row
# 2529 processed row
# 2530 processed row
# 2531 processed row
# 2532 processed row
# 2533 processed row
# 2534 processed row
# 2535 processed row
# 2536 processed row
# 2537 processed row
# 2538 processed row
# 2539 processed row
# 2540 processed row
# 2541 processed row
# 2542 processed row
# 2543 processed row
# 2544 processed row
# 2545 processed row
# 2546 processed row
# 2547 processed row
# 2548 processed row
# 2549 processed row
# 2550 processed row
# 2551 processed row
# 2552 processed row
# 2553 processed row
# 2554 processed row
# 2555 processed row
# 2556 processed row
# 2557 processed row
# 2558 processed row
# 2559 processed row
# 2560 processed row
# 2561 processed row
# 2562 processed row
# 2563 processed row
# 2564 processed row
# 2565 processed row
# 2566 processed row
# 2567 processed row
# 2568 processed row
# 2569 processed row
# 2570 processed row
# 2571 processed row
# 2572 processed row
# 2573 processed row
# 2574 processed row
# 2575 processed row
# 2576 processed row
# 2577 processed row
# 2578 processed row
# 2579 processed row
# 2580 processed row
# 2581 processed row
# 2582 processed row
# 2583 processed row
# ...
# 14169 processed row
# 14170 processed row
# 14171 processed row
# 14172 processed row
# 14173 processed row
# 14174 processed row
# 14175 processed row
# 14176 processed row
# 14177 processed row
# 14178 processed row
# 14179 processed row
# 14180 processed row
# 14181 processed row
# 14182 processed row
# 14183 processed row
# 14184 processed row
# 14185 processed row
# 14186 processed row
# 14187 processed row
# 14188 processed row
# 14189 processed row
# 14190 processed row
# 14191 processed row
# 14192 processed row
# 14193 processed row
# 14194 processed row
# 14195 processed row
# 14196 processed row
# 14197 processed row
# 14198 processed row
# 14199 processed row
# 14200 processed row
# 14201 processed row
# 14202 processed row
# 14203 processed row
# 14204 processed row
# 14205 processed row
# 14206 processed row
# 14207 processed row
# 14208 processed row
# 14209 processed row
# 14210 processed row
# 14211 processed row
# 14212 processed row
# 14213 processed row
# 14214 processed row
# 14215 processed row
# 14216 processed row
# 14217 processed row
# 14218 processed row
# 14219 processed row
# 14220 processed row
# 14221 processed row
# 14222 processed row
# 14223 processed row
# 14224 processed row
# 14225 processed row
# 14226 processed row
# 14227 processed row
# 14228 processed row
# 14229 processed row
# 14230 processed row
# 14231 processed row
# 14232 processed row
# 14233 processed row
# 14234 processed row
# 14235 processed row
# 14236 processed row
# 14237 processed row
# 14238 processed row
# 14239 processed row
# 14240 processed row
# 14241 processed row
# 14242 processed row
# 14243 processed row
# 14244 processed row
# 14245 processed row
# 14246 processed row
# 14247 processed row
# 14248 processed row
# 14249 processed row
# 14250 processed row
# 14251 processed row
# 14252 processed row
# 14253 processed row
# 14254 processed row
# 14255 processed row
# 14256 processed row
# 14257 processed row
# 14258 processed row
# 14259 processed row
# 14260 processed row
# 14261 processed row
# 14262 processed row
# 14263 processed row
# 14264 processed row
# 14265 processed row
# 14266 processed row
# 14267 processed row
# 14268 processed row
# 14269 processed row
# 14270 processed row
# 14271 processed row
# 14272 processed row
# 14273 processed row
# 14274 processed row
# 14275 processed row
# 14276 processed row
# 14277 processed row
# 14278 processed row
# 14279 processed row
# 14280 processed row
# 14281 processed row
# 14282 processed row
# 14283 processed row
# 14284 processed row
# 14285 processed row
# 14286 processed row
# 14287 processed row
# 14288 processed row
# 14289 processed row
# 14290 processed row
# 14291 processed row
# 14292 processed row
# 14293 processed row
# 14294 processed row
# 14295 processed row
# 14296 processed row
# 14297 processed row
# 14298 processed row
# 14299 processed row
# 14300 processed row
# 14301 processed row
# 14302 processed row
# 14303 processed row
# 14304 processed row
# 14305 processed row
# 14306 processed row
# 14307 processed row
# 14308 processed row
# 14309 processed row
# 14310 processed row
# 14311 processed row
# 14312 processed row
# 14313 processed row
# 14314 processed row
# 14315 processed row
# 14316 processed row
# 14317 processed row
# 14318 processed row
# 14319 processed row
# 14320 processed row
# 14321 processed row
# 14322 processed row
# 14323 processed row
# 14324 processed row
# 14325 processed row
# 14326 processed row
# 14327 processed row
# 14328 processed row
# 14329 processed row
# 14330 processed row
# 14331 processed row
# 14332 processed row
# 14333 processed row
# 14334 processed row
# 14335 processed row
# 14336 processed row
# 14337 processed row
# 14338 processed row
# 14339 processed row
# 14340 processed row
# 14341 processed row
# 14342 processed row
# 14343 processed row
# 14344 processed row
# 14345 processed row
# 14346 processed row
# 14347 processed row
# 14348 processed row
# 14349 processed row
# 14350 processed row
# 14351 processed row
# 14352 processed row
# 14353 processed row
# 14354 processed row
# 14355 processed row
# 14356 processed row
# 14357 processed row
# 14358 processed row
# 14359 processed row
# 14360 processed row
# 14361 processed row
# 14362 processed row
# 14363 processed row
# 14364 processed row
# 14365 processed row
# 14366 processed row
# 14367 processed row
# 14368 processed row
# 14369 processed row
# 14370 processed row
# 14371 processed row
# 14372 processed row
# 14373 processed row
# 14374 processed row
# 14375 processed row
# 14376 processed row
# 14377 processed row
# 14378 processed row
# 14379 processed row
# 14380 processed row
# 14381 processed row
# 14382 processed row
# 14383 processed row
# 14384 processed row
# 14385 processed row
# 14386 processed row
# 14387 processed row
# 14388 processed row
# 14389 processed row
# 14390 processed row
# 14391 processed row
# 14392 processed row
# 14393 processed row
# 14394 processed row
# 14395 processed row
# 14396 processed row
# 14397 processed row
# 14398 processed row
# 14399 processed row
# 14400 processed row
# 14401 processed row
# 14402 processed row
# 14403 processed row
# 14404 processed row
# 14405 processed row
# 14406 processed row
# 14407 processed row
# 14408 processed row
# 14409 processed row
# 14410 processed row
# 14411 processed row
# 14412 processed row
# 14413 processed row
# 14414 processed row
# 14415 processed row
# 14416 processed row
# 14417 processed row
# 14418 processed row
# 14419 processed row
# 14420 processed row
# 14421 processed row
# 14422 processed row
# 14423 processed row
# 14424 processed row
# 14425 processed row
# 14426 processed row
# 14427 processed row
# 14428 processed row
# 14429 processed row
# 14430 processed row
# 14431 processed row
# 14432 processed row
# 14433 processed row
# 14434 processed row
# 14435 processed row
# 14436 processed row
# 14437 processed row
# 14438 processed row
# 14439 processed row
# 14440 processed row
# 14441 processed row
# 14442 processed row
# 14443 processed row
# 14444 processed row
# 14445 processed row
# 14446 processed row
# 14447 processed row
# 14448 processed row
# 14449 processed row
# 14450 processed row
# 14451 processed row
# 14452 processed row
# 14453 processed row
# 14454 processed row
# 14455 processed row
# 14456 processed row
# 14457 processed row
# 14458 processed row
# 14459 processed row
# 14460 processed row
# 14461 processed row
# 14462 processed row
# 14463 processed row
# 14464 processed row
# 14465 processed row
# 14466 processed row
# 14467 processed row
# 14468 processed row
# 14469 processed row
# 14470 processed row
# 14471 processed row
# 14472 processed row
# 14473 processed row
# 14474 processed row
# 14475 processed row
# 14476 processed row
# 14477 processed row
# 14478 processed row
# 14479 processed row
# 14480 processed row
# 14481 processed row
# 14482 processed row
# 14483 processed row
# 14484 processed row
# 14485 processed row
# 14486 processed row
# 14487 processed row
# 14488 processed row
# 14489 processed row
# 14490 processed row
# 14491 processed row
# 14492 processed row
# 14493 processed row
# 14494 processed row
# 14495 processed row
# 14496 processed row
# 14497 processed row
# 14498 processed row
# 14499 processed row
# 14500 processed row
# 14501 processed row
# 14502 processed row
# 14503 processed row
# 14504 processed row
# 14505 processed row
# 14506 processed row
# 14507 processed row
# 14508 processed row
# 14509 processed row
# 14510 processed row
# 14511 processed row
# 14512 processed row
# 14513 processed row
# 14514 processed row
# 14515 processed row
# 14516 processed row
# 14517 processed row
# 14518 processed row
# 14519 processed row
# 14520 processed row
# 14521 processed row
# 14522 processed row
# 14523 processed row
# 14524 processed row
# 14525 processed row
# 14526 processed row
# 14527 processed row
# 14528 processed row
# 14529 processed row
# 14530 processed row
# 14531 processed row
# 14532 processed row
# 14533 processed row
# 14534 processed row
# 14535 processed row
# 14536 processed row
# 14537 processed row
# 14538 processed row
# 14539 processed row
# 14540 processed row
# 14541 processed row
# 14542 processed row
# 14543 processed row
# 14544 processed row
# 14545 processed row
# 14546 processed row
# 14547 processed row
# 14548 processed row
# 14549 processed row
# 14550 processed row
# 14551 processed row
# 14552 processed row
# 14553 processed row
# 14554 processed row
# 14555 processed row
# 14556 processed row
# 14557 processed row
# 14558 processed row
# 14559 processed row
# 14560 processed row
# 14561 processed row
# 14562 processed row
# 14563 processed row
# 14564 processed row
# 14565 processed row
# 14566 processed row
# 14567 processed row
# 14568 processed row
# 14569 processed row
# 14570 processed row
# 14571 processed row
# 14572 processed row
# 14573 processed row
# 14574 processed row
# 14575 processed row
# 14576 processed row
# 14577 processed row
# 14578 processed row
# 14579 processed row
# 14580 processed row
# 14581 processed row
# 14582 processed row
# 14583 processed row
# 14584 processed row
# 14585 processed row
# 14586 processed row
# 14587 processed row
# 14588 processed row
# 14589 processed row
# 14590 processed row
# 14591 processed row
# 14592 processed row
# 14593 processed row
# 14594 processed row
# 14595 processed row
# 14596 processed row
# 14597 processed row
# 14598 processed row
# 14599 processed row
# 14600 processed row
# 14601 processed row
# 14602 processed row
# 14603 processed row
# 14604 processed row
# 14605 processed row
# 14606 processed row
# 14607 processed row
# 14608 processed row
# 14609 processed row
# 14610 processed row
# 14611 processed row
# 14612 processed row
# 14613 processed row
# 14614 processed row
# 14615 processed row
# 14616 processed row
# 14617 processed row
# 14618 processed row
# 14619 processed row
# 14620 processed row
# 14621 processed row
# 14622 processed row
# 14623 processed row
# 14624 processed row
# 14625 processed row
# 14626 processed row
# 14627 processed row
# 14628 processed row
# 14629 processed row
# 14630 processed row
# 14631 processed row
# 14632 processed row
# 14633 processed row
# 14634 processed row
# 14635 processed row
# 14636 processed row
# 14637 processed row
# 14638 processed row
# 14639 processed row
# 14640 processed row
# 14641 processed row
# 14642 processed row
# 14643 processed row
# 14644 processed row
# 14645 processed row
# 14646 processed row
# 14647 processed row
# 14648 processed row
# 14649 processed row
# 14650 processed row
# 14651 processed row
# 14652 processed row
# 14653 processed row
# 14654 processed row
# 14655 processed row
# 14656 processed row
# 14657 processed row
# 14658 processed row
# 14659 processed row
# 14660 processed row
# 14661 processed row
# 14662 processed row
# 14663 processed row
# 14664 processed row
# 14665 processed row
# 14666 processed row
# 14667 processed row
# 14668 processed row
# 14669 processed row
# 14670 processed row
# 14671 processed row
# 14672 processed row
# 14673 processed row
# 14674 processed row
# 14675 processed row
# 14676 processed row
# 14677 processed row
# 14678 processed row
# 14679 processed row
# 14680 processed row
# 14681 processed row
# 14682 processed row
# 14683 processed row
# 14684 processed row
# 14685 processed row
# 14686 processed row
# 14687 processed row
# 14688 processed row
# 14689 processed row
# 14690 processed row
# 14691 processed row
# 14692 processed row
# 14693 processed row
# 14694 processed row
# 14695 processed row
# 14696 processed row
# 14697 processed row
# 14698 processed row
# 14699 processed row
# 14700 processed row
# 14701 processed row
# 14702 processed row
# 14703 processed row
# 14704 processed row
# 14705 processed row
# 14706 processed row
# 14707 processed row
# 14708 processed row
# 14709 processed row
# 14710 processed row
# 14711 processed row
# 14712 processed row
# 14713 processed row
# 14714 processed row
# 14715 processed row
# 14716 processed row
# 14717 processed row
# 14718 processed row
# 14719 processed row
# 14720 processed row
# 14721 processed row
# 14722 processed row
# 14723 processed row
# 14724 processed row
# 14725 processed row
# 14726 processed row
# 14727 processed row
# 14728 processed row
# 14729 processed row
# 14730 processed row
# 14731 processed row
# 14732 processed row
# 14733 processed row
# 14734 processed row
# 14735 processed row
# 14736 processed row
# 14737 processed row
# 14738 processed row
# 14739 processed row
# 14740 processed row
# 14741 processed row
# 14742 processed row
# 14743 processed row
# 14744 processed row
# 14745 processed row
# 14746 processed row
# 14747 processed row
# 14748 processed row
# 14749 processed row
# 14750 processed row
# 14751 processed row
# 14752 processed row
# 14753 processed row
# 14754 processed row
# 14755 processed row
# 14756 processed row
# 14757 processed row
# 14758 processed row
# 14759 processed row
# 14760 processed row
# 14761 processed row
# 14762 processed row
# 14763 processed row
# 14764 processed row
# 14765 processed row
# 14766 processed row
# 14767 processed row
# 14768 processed row
# 14769 processed row
# 14770 processed row
# 14771 processed row
# 14772 processed row
# 14773 processed row
# 14774 processed row
# 14775 processed row
# 14776 processed row
# 14777 processed row
# 14778 processed row
# 14779 processed row
# 14780 processed row
# 14781 processed row
# 14782 processed row
# 14783 processed row
# 14784 processed row
# 14785 processed row
# 14786 processed row
# 14787 processed row
# 14788 processed row
# 14789 processed row
# 14790 processed row
# 14791 processed row
# 14792 processed row
# 14793 processed row
# 14794 processed row
# 14795 processed row
# 14796 processed row
# 14797 processed row
# 14798 processed row
# 14799 processed row
# 14800 processed row
# 14801 processed row
# 14802 processed row
# 14803 processed row
# 14804 processed row
# 14805 processed row
# 14806 processed row
# 14807 processed row
# 14808 processed row
# 14809 processed row
# 14810 processed row
# 14811 processed row
# 14812 processed row
# 14813 processed row
# 14814 processed row
# 14815 processed row
# 14816 processed row
# 14817 processed row
# 14818 processed row
# 14819 processed row
# 14820 processed row
# 14821 processed row
# 14822 processed row
# 14823 processed row
# 14824 processed row
# 14825 processed row
# 14826 processed row
# 14827 processed row
# 14828 processed row
# 14829 processed row
# 14830 processed row
# 14831 processed row
# 14832 processed row
# 14833 processed row
# 14834 processed row
# 14835 processed row
# 14836 processed row
# 14837 processed row
# 14838 processed row
# 14839 processed row
# 14840 processed row
# 14841 processed row
# 14842 processed row
# 14843 processed row
# 14844 processed row
# 14845 processed row
# 14846 processed row
# 14847 processed row
# 14848 processed row
# 14849 processed row
# 14850 processed row
# 14851 processed row
# 14852 processed row
# 14853 processed row
# 14854 processed row
# 14855 processed row
# 14856 processed row
# 14857 processed row
# 14858 processed row
# 14859 processed row
# 14860 processed row
# 14861 processed row
# 14862 processed row
# 14863 processed row
# 14864 processed row
# 14865 processed row
# 14866 processed row
# 14867 processed row
# 14868 processed row
# 14869 processed row
# 14870 processed row
# 14871 processed row
# 14872 processed row
# 14873 processed row
# 14874 processed row
# 14875 processed row
# 14876 processed row
# 14877 processed row
# 14878 processed row
# 14879 processed row
# 14880 processed row
# 14881 processed row
# 14882 processed row
# 14883 processed row
# 14884 processed row
# 14885 processed row
# 14886 processed row
# 14887 processed row
# 14888 processed row
# 14889 processed row
# 14890 processed row
# 14891 processed row
# 14892 processed row
# 14893 processed row
# 14894 processed row
# 14895 processed row
# 14896 processed row
# 14897 processed row
# 14898 processed row
# 14899 processed row
# 14900 processed row
# 14901 processed row
# 14902 processed row
# 14903 processed row
# 14904 processed row
# 14905 processed row
# 14906 processed row
# 14907 processed row
# 14908 processed row
# 14909 processed row
# 14910 processed row
# 14911 processed row
# 14912 processed row
# 14913 processed row
# 14914 processed row
# 14915 processed row
# 14916 processed row
# 14917 processed row
# 14918 processed row
# 14919 processed row
# 14920 processed row
# 14921 processed row
# 14922 processed row
# 14923 processed row
# 14924 processed row
# 14925 processed row
# 14926 processed row
# 14927 processed row
# 14928 processed row
# 14929 processed row
# 14930 processed row
# 14931 processed row
# 14932 processed row
# 14933 processed row
# 14934 processed row
# 14935 processed row
# 14936 processed row
# 14937 processed row
# 14938 processed row
# 14939 processed row
# 14940 processed row
# 14941 processed row
# 14942 processed row
# 14943 processed row
# 14944 processed row
# 14945 processed row
# 14946 processed row
# 14947 processed row
# 14948 processed row
# 14949 processed row
# 14950 processed row
# 14951 processed row
# 14952 processed row
# 14953 processed row
# 14954 processed row
# 14955 processed row
# 14956 processed row
# 14957 processed row
# 14958 processed row
# 14959 processed row
# 14960 processed row
# 14961 processed row
# 14962 processed row
# 14963 processed row
# 14964 processed row
# 14965 processed row
# 14966 processed row
# 14967 processed row
# 14968 processed row

# %%
#This file does not contain the column with some issues and errors overlooked by the prior code.
#But it is useful to save the data with the already determined column'Smiles_curated' at this point.

df.to_excel('data_curated.xlsx')
#df

# %%
#Highlight issues and errors

# Thes molvs 'validate_smiles()' function detects several issues and errors in molecules that were not corrected during the curation process because 
# cannot be corrected automatically, nonetheless, a column that highlights the issues and errors is added and theses compounds can be manually removed. 

# ¡¡¡¡NOT ALL THE ISSUES THAT ARE DETECTED BY 'validate_smiles()' IMPLIES THE REMOVAL OF MOLECULES!!!! that depends on the criteria of the person.

# For instance, this function highlights the molecules with charge different than cero and molecules with isotopic information anotated and these
# molecules not neccesarily should be removed.

def validation(x,y): #Highlights the errors in the molecules
    try:
        a=validate_smiles(x)                                      
        if a:                                                     #If the list is not empty, that is to say, if was found an alert.
            print(f"{y} processed row MolVs issue founds")
            return a
        else:                                                     #Verifies if the smiles contain different atoms than the allowed. Thank to Ana Chávez for this block of code. 
            mol = Chem.MolFromSmiles(x, sanitize=True)            #The molecule with a different element than the allowed is highlighted, but not eliminated.
            allowed_elements = {"C","H","O","N","P","S","F","Cl","Br","I","B","Si","Se"}  #Can be added or removed atoms to this list.
            actual_elements = set([atom.GetSymbol() for atom in mol.GetAtoms()])
            if len(actual_elements-allowed_elements) != 0:
                print(f"{y} processed row Allowed elements issue found")
                return 'Contains elements different than the allowed'
    except:
        pass

# %%
#Highlight the issues and errors in the not curated smiles

#A column that highlights the errors or issues with the molecules is added.
#Useful to compare the non curated SMILES to the curated smiles and visualize some errors that were corrected during the curation process.
df["Issues_in_NOT_curated_smiles"] = [validation(i,j) for i,j in zip(df["Smiles"],df.index)]
# Out:
# 630 processed row MolVs issue founds
# 631 processed row MolVs issue founds
# 664 processed row MolVs issue founds
# 665 processed row MolVs issue founds
# 666 processed row MolVs issue founds
# 667 processed row MolVs issue founds
# 1231 processed row MolVs issue founds
# 2813 processed row MolVs issue founds
# 2814 processed row MolVs issue founds
# 2915 processed row MolVs issue founds
# 2916 processed row MolVs issue founds
# 3036 processed row MolVs issue founds
# 3037 processed row MolVs issue founds
# 3064 processed row MolVs issue founds
# 3069 processed row MolVs issue founds
# 3070 processed row MolVs issue founds
# 3160 processed row MolVs issue founds
# 8167 processed row MolVs issue founds
# 8407 processed row MolVs issue founds
# 8408 processed row MolVs issue founds
# 8410 processed row MolVs issue founds
# 8611 processed row MolVs issue founds
# 8734 processed row MolVs issue founds
# 8823 processed row MolVs issue founds
# 8824 processed row MolVs issue founds
# 8827 processed row MolVs issue founds
# 8850 processed row MolVs issue founds
# 8851 processed row MolVs issue founds
# 8860 processed row MolVs issue founds
# 8949 processed row MolVs issue founds
# 8950 processed row MolVs issue founds
# 8962 processed row MolVs issue founds
# 8988 processed row MolVs issue founds
# 9009 processed row MolVs issue founds
# 9020 processed row MolVs issue founds
# 9031 processed row MolVs issue founds
# 9042 processed row MolVs issue founds
# 9068 processed row MolVs issue founds
# 9086 processed row MolVs issue founds
# 9091 processed row MolVs issue founds
# 9099 processed row MolVs issue founds
# 9116 processed row MolVs issue founds
# 9120 processed row MolVs issue founds
# 9241 processed row MolVs issue founds
# 9254 processed row MolVs issue founds
# 9258 processed row MolVs issue founds
# 9260 processed row MolVs issue founds
# 9270 processed row MolVs issue founds
# 9299 processed row MolVs issue founds
# 9305 processed row MolVs issue founds
# 9307 processed row MolVs issue founds
# 9308 processed row MolVs issue founds
# 9312 processed row MolVs issue founds
# 9314 processed row MolVs issue founds
# 9320 processed row MolVs issue founds
# 9413 processed row MolVs issue founds
# 9539 processed row MolVs issue founds
# 9541 processed row MolVs issue founds
# 9686 processed row MolVs issue founds
# 9687 processed row MolVs issue founds
# 9738 processed row MolVs issue founds
# 9739 processed row MolVs issue founds
# 9748 processed row MolVs issue founds
# 9749 processed row MolVs issue founds
# 9752 processed row MolVs issue founds
# 9758 processed row MolVs issue founds
# 9759 processed row MolVs issue founds
# 9890 processed row MolVs issue founds
# 9891 processed row MolVs issue founds
# 10137 processed row MolVs issue founds
# 10138 processed row MolVs issue founds
# 10139 processed row MolVs issue founds
# 10140 processed row MolVs issue founds
# 10144 processed row MolVs issue founds
# 10145 processed row MolVs issue founds
# 11898 processed row MolVs issue founds
# 11901 processed row MolVs issue founds
# 11907 processed row MolVs issue founds
# 11915 processed row MolVs issue founds
# 12277 processed row MolVs issue founds
# 12310 processed row MolVs issue founds
# 12894 processed row MolVs issue founds
# 13183 processed row MolVs issue founds
# 14816 processed row MolVs issue founds
# 14903 processed row MolVs issue founds
# 14909 processed row MolVs issue founds
# 14923 processed row MolVs issue founds
# 14925 processed row MolVs issue founds
# C:\Users\alexg\AppData\Local\Temp\ipykernel_8752\4250162888.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Issues_in_NOT_curated_smiles"] = [validation(i,j) for i,j in zip(df["Smiles"],df.index)]

# %%
#Highlight the errors in the curated smiles
df["Issues_in_curated_smiles"] = [validation(i,j) for i,j in zip(df["Smiles_curated"],df.index)]
# Out:
# 630 processed row MolVs issue founds
# 631 processed row MolVs issue founds
# 664 processed row MolVs issue founds
# 665 processed row MolVs issue founds
# 666 processed row MolVs issue founds
# 667 processed row MolVs issue founds
# 1231 processed row MolVs issue founds
# 2813 processed row MolVs issue founds
# 2814 processed row MolVs issue founds
# 2915 processed row MolVs issue founds
# 2916 processed row MolVs issue founds
# 3036 processed row MolVs issue founds
# 3037 processed row MolVs issue founds
# 3064 processed row MolVs issue founds
# 3069 processed row MolVs issue founds
# 3070 processed row MolVs issue founds
# 3160 processed row MolVs issue founds
# 8167 processed row MolVs issue founds
# 8407 processed row MolVs issue founds
# 8408 processed row MolVs issue founds
# 8410 processed row MolVs issue founds
# 8611 processed row MolVs issue founds
# 8734 processed row MolVs issue founds
# 8823 processed row MolVs issue founds
# 8824 processed row MolVs issue founds
# 8827 processed row MolVs issue founds
# 8850 processed row MolVs issue founds
# 8851 processed row MolVs issue founds
# 8860 processed row MolVs issue founds
# 8949 processed row MolVs issue founds
# 8950 processed row MolVs issue founds
# 8962 processed row MolVs issue founds
# 8988 processed row MolVs issue founds
# 9009 processed row MolVs issue founds
# 9020 processed row MolVs issue founds
# 9031 processed row MolVs issue founds
# 9042 processed row MolVs issue founds
# 9068 processed row MolVs issue founds
# 9086 processed row MolVs issue founds
# 9091 processed row MolVs issue founds
# 9099 processed row MolVs issue founds
# 9116 processed row MolVs issue founds
# 9120 processed row MolVs issue founds
# 9241 processed row MolVs issue founds
# 9254 processed row MolVs issue founds
# 9258 processed row MolVs issue founds
# 9260 processed row MolVs issue founds
# 9270 processed row MolVs issue founds
# 9299 processed row MolVs issue founds
# 9305 processed row MolVs issue founds
# 9307 processed row MolVs issue founds
# 9308 processed row MolVs issue founds
# 9312 processed row MolVs issue founds
# 9314 processed row MolVs issue founds
# 9320 processed row MolVs issue founds
# 9413 processed row MolVs issue founds
# 9539 processed row MolVs issue founds
# 9541 processed row MolVs issue founds
# 9686 processed row MolVs issue founds
# 9687 processed row MolVs issue founds
# 9738 processed row MolVs issue founds
# 9739 processed row MolVs issue founds
# 9748 processed row MolVs issue founds
# 9749 processed row MolVs issue founds
# 9752 processed row MolVs issue founds
# 9758 processed row MolVs issue founds
# 9759 processed row MolVs issue founds
# 9890 processed row MolVs issue founds
# 9891 processed row MolVs issue founds
# 10137 processed row MolVs issue founds
# 10138 processed row MolVs issue founds
# 10139 processed row MolVs issue founds
# 10140 processed row MolVs issue founds
# 10144 processed row MolVs issue founds
# 10145 processed row MolVs issue founds
# 11898 processed row MolVs issue founds
# 11901 processed row MolVs issue founds
# 11907 processed row MolVs issue founds
# 11915 processed row MolVs issue founds
# 12277 processed row MolVs issue founds
# 12310 processed row MolVs issue founds
# 12894 processed row MolVs issue founds
# 13183 processed row MolVs issue founds
# 14816 processed row MolVs issue founds
# 14903 processed row MolVs issue founds
# 14909 processed row MolVs issue founds
# 14923 processed row MolVs issue founds
# 14925 processed row MolVs issue founds
# C:\Users\alexg\AppData\Local\Temp\ipykernel_8752\3184218998.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Issues_in_curated_smiles"] = [validation(i,j) for i,j in zip(df["Smiles_curated"],df.index)]

# %%
df.to_excel('data_curated_issues_or_errors_highlighted.xlsx')

# %%
# Pairs of duplicates table

#This table allows to identify the compounds which were pair of duplicates.

# Reset the index to have the original indices as a column
duplicates = duplicates.reset_index()

# Merge the DataFrame with itself to get the pairs, including the original indices
pairs_df = duplicates.merge(duplicates, on='Smiles_curated', suffixes=('_left', '_right'))

# Remove duplicate pairs (rows repeated in reverse order)
pairs_df = pairs_df[pairs_df['index_left'] < pairs_df['index_right']]

# Save the resulting pairs to an Excel file
pairs_df.to_excel('duplicates.xlsx', index=False)
